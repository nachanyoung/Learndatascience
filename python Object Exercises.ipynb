# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
class Circle (object):
    #constructor
    def __init__(self,radius,color):
        self.radius=radius
        self.color=color
      #method  
    def addradius(self,r):
        self.radius=self.radius+r
        return (self.radius)
    #method
    def drawCircle(self):
        plt.gca().add_patch(plt.Circle((0, 0), radius=self.radius, fc=self.color))
        plt.axis('scaled')
        plt.show()

# %%
Redcircle = Circle(10, 'red')

# %%
dir(Redcircle)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'addradius',
#  'color',
#  'drawCircle',
#  'radius']

# %%
Redcircle.radius
# Out:
# 10

# %%
Redcircle.color
# Out:
# 'red'

# %%
Redcircle.radius
# Out:
# 10

# %%
Redcircle.radius=1
Redcircle.radius
# Out:
# 1

# %%
Redcircle.drawCircle()

# %%
Redcircle.addradius(3)
# Out:
# 4

# %%
Redcircle.drawCircle()

# %%
Bluecircle=Circle(9, 'blue')

# %%
Bluecircle.drawCircle()

# %%
class Rectangle (object):
    def __init__(self, width=2, height=4, color='r'):
        self.width=width
        self.height=height
        self.color=color
        
    def drawRectangle(self):
        plt.gca().add_patch(plt.Rectangle((0,0), self.width, self.height, fc=self.color))
        plt.axis('scaled')
        plt.show()

# %%
Rectangle.drawRectangle()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 Rectangle.drawRectangle()
#
# TypeError: Rectangle.drawRectangle() missing 1 required positional argument: 'self'

# %%
Bluerect= Rectangle(4,2,'blue')

# %%
Bluerect.drawRectangle()
